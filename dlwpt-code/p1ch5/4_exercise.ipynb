# %%
import torch
import matplotlib.pyplot as plt

# %%
t_c = torch.tensor([0.5, 14.0, 15.0, 28.0, 11.0,
                    8.0, 3.0, -4.0, 6.0, 13.0, 21.0])
t_u = torch.tensor([35.7, 55.9, 58.2, 81.9, 56.3, 48.9,
                    33.9, 21.8, 48.4, 60.4, 68.4])
t_un = 0.1 * t_u

n_samples = t_u.shape[0]
n_vals = int(0.2 * n_samples)

shuffed_indieces = torch.randperm(n_samples)
train_indieces = shuffed_indieces[0:-n_vals]
val_indieces = shuffed_indieces[-n_vals:]

train_t_u   = t_un[train_indieces]
val_t_u     = t_un[val_indieces]
train_t_c   = t_c[train_indieces]
val_t_c     = t_c[val_indieces]

# %%
def model(t_u, w2, w1, b):
    return w1 * t_u ** 2  + w2 * t_u ** 2 + b

def model_1(t_u, w, b):
    return w * t_u + b

def loss_fn(t_p, t_c):
    loss = (t_p - t_c) ** 2
    return loss.mean()

# %%
def training_loop(n_epochs, optimizer, model, params,                                        train_t_u, train_t_c, val_t_u, val_t_c):
    for epoch in range(1, n_epochs + 1):
        train_t_p = model(train_t_u, *params)
        train_loss = loss_fn(train_t_p, train_t_c)

        # with torch.no_grad():
        val_t_p     = model(val_t_u, *params)
        val_loss    = loss_fn(val_t_p, val_t_c)

        optimizer.zero_grad()
        train_loss.backward()
        optimizer.step()

        if epoch <= 3 or epoch % 100 == 0:
            print(f"Epoch {epoch}, Training loss {train_loss.item():.4f}," +
                    f" Validation loss {val_loss.item():.4f}")
            print('   params', params)
            print()

params = torch.tensor([1.0, 1.0, 0.0], requires_grad = True)

optimizer = torch.optim.SGD([params], lr = 1e-4)

training_loop(
        n_epochs = 10000,
        optimizer = optimizer,
        model = model,
        params = params,
        train_t_u = train_t_u,
        train_t_c = train_t_c,
        val_t_u = val_t_u,
        val_t_c = val_t_c)
# Out:
# Epoch 1, Training loss 1770.6245, Validation loss 8267.4365
#    params tensor([ 0.7851,  0.7851, -0.0078], requires_grad=True)
#
# Epoch 2, Training loss 967.3392, Validation loss 4364.1074
#    params tensor([ 0.6265,  0.6265, -0.0137], requires_grad=True)
#
# Epoch 3, Training loss 530.1371, Validation loss 2277.1157
#    params tensor([ 0.5095,  0.5095, -0.0180], requires_grad=True)
#
# Epoch 100, Training loss 7.9634, Validation loss 15.7404
#    params tensor([ 0.1808,  0.1808, -0.0489], requires_grad=True)
#
# Epoch 200, Training loss 7.9248, Validation loss 15.5837
#    params tensor([ 0.1811,  0.1811, -0.0685], requires_grad=True)
#
# Epoch 300, Training loss 7.8864, Validation loss 15.4285
#    params tensor([ 0.1815,  0.1815, -0.0881], requires_grad=True)
#
# Epoch 400, Training loss 7.8483, Validation loss 15.2746
#    params tensor([ 0.1818,  0.1818, -0.1076], requires_grad=True)
#
# Epoch 500, Training loss 7.8104, Validation loss 15.1222
#    params tensor([ 0.1822,  0.1822, -0.1271], requires_grad=True)
#
# Epoch 600, Training loss 7.7728, Validation loss 14.9713
#    params tensor([ 0.1825,  0.1825, -0.1464], requires_grad=True)
#
# Epoch 700, Training loss 7.7355, Validation loss 14.8217
#    params tensor([ 0.1829,  0.1829, -0.1657], requires_grad=True)
#
# Epoch 800, Training loss 7.6984, Validation loss 14.6735
#    params tensor([ 0.1832,  0.1832, -0.1850], requires_grad=True)
#
# Epoch 900, Training loss 7.6616, Validation loss 14.5267
#    params tensor([ 0.1836,  0.1836, -0.2042], requires_grad=True)
#
# Epoch 1000, Training loss 7.6250, Validation loss 14.3812
#    params tensor([ 0.1839,  0.1839, -0.2233], requires_grad=True)
#
# Epoch 1100, Training loss 7.5887, Validation loss 14.2372
#    params tensor([ 0.1842,  0.1842, -0.2423], requires_grad=True)
#
# Epoch 1200, Training loss 7.5527, Validation loss 14.0944
#    params tensor([ 0.1846,  0.1846, -0.2613], requires_grad=True)
#
# Epoch 1300, Training loss 7.5168, Validation loss 13.9530
#    params tensor([ 0.1849,  0.1849, -0.2803], requires_grad=True)
#
# Epoch 1400, Training loss 7.4813, Validation loss 13.8129
#    params tensor([ 0.1852,  0.1852, -0.2991], requires_grad=True)
#
# Epoch 1500, Training loss 7.4459, Validation loss 13.6741
#    params tensor([ 0.1856,  0.1856, -0.3179], requires_grad=True)
#
# Epoch 1600, Training loss 7.4108, Validation loss 13.5367
#    params tensor([ 0.1859,  0.1859, -0.3366], requires_grad=True)
#
# Epoch 1700, Training loss 7.3760, Validation loss 13.4005
#    params tensor([ 0.1862,  0.1862, -0.3553], requires_grad=True)
#
# Epoch 1800, Training loss 7.3414, Validation loss 13.2656
#    params tensor([ 0.1866,  0.1866, -0.3739], requires_grad=True)
#
# Epoch 1900, Training loss 7.3070, Validation loss 13.1320
#    params tensor([ 0.1869,  0.1869, -0.3924], requires_grad=True)
#
# Epoch 2000, Training loss 7.2729, Validation loss 12.9997
#    params tensor([ 0.1872,  0.1872, -0.4109], requires_grad=True)
#
# Epoch 2100, Training loss 7.2389, Validation loss 12.8686
#    params tensor([ 0.1876,  0.1876, -0.4293], requires_grad=True)
#
# Epoch 2200, Training loss 7.2053, Validation loss 12.7387
#    params tensor([ 0.1879,  0.1879, -0.4476], requires_grad=True)
#
# Epoch 2300, Training loss 7.1718, Validation loss 12.6101
#    params tensor([ 0.1882,  0.1882, -0.4659], requires_grad=True)
#
# Epoch 2400, Training loss 7.1386, Validation loss 12.4827
#    params tensor([ 0.1885,  0.1885, -0.4841], requires_grad=True)
#
# Epoch 2500, Training loss 7.1056, Validation loss 12.3566
#    params tensor([ 0.1889,  0.1889, -0.5023], requires_grad=True)
#
# Epoch 2600, Training loss 7.0729, Validation loss 12.2316
#    params tensor([ 0.1892,  0.1892, -0.5204], requires_grad=True)
#
# Epoch 2700, Training loss 7.0403, Validation loss 12.1078
#    params tensor([ 0.1895,  0.1895, -0.5384], requires_grad=True)
#
# Epoch 2800, Training loss 7.0080, Validation loss 11.9852
#    params tensor([ 0.1898,  0.1898, -0.5564], requires_grad=True)
#
# Epoch 2900, Training loss 6.9759, Validation loss 11.8638
#    params tensor([ 0.1901,  0.1901, -0.5743], requires_grad=True)
#
# Epoch 3000, Training loss 6.9441, Validation loss 11.7436
#    params tensor([ 0.1904,  0.1904, -0.5921], requires_grad=True)
#
# Epoch 3100, Training loss 6.9124, Validation loss 11.6245
#    params tensor([ 0.1908,  0.1908, -0.6099], requires_grad=True)
#
# Epoch 3200, Training loss 6.8810, Validation loss 11.5066
#    params tensor([ 0.1911,  0.1911, -0.6277], requires_grad=True)
#
# Epoch 3300, Training loss 6.8498, Validation loss 11.3898
#    params tensor([ 0.1914,  0.1914, -0.6453], requires_grad=True)
#
# Epoch 3400, Training loss 6.8188, Validation loss 11.2742
#    params tensor([ 0.1917,  0.1917, -0.6629], requires_grad=True)
#
# Epoch 3500, Training loss 6.7880, Validation loss 11.1597
#    params tensor([ 0.1920,  0.1920, -0.6805], requires_grad=True)
#
# Epoch 3600, Training loss 6.7574, Validation loss 11.0462
#    params tensor([ 0.1923,  0.1923, -0.6979], requires_grad=True)
#
# Epoch 3700, Training loss 6.7270, Validation loss 10.9339
#    params tensor([ 0.1926,  0.1926, -0.7154], requires_grad=True)
#
# Epoch 3800, Training loss 6.6968, Validation loss 10.8227
#    params tensor([ 0.1929,  0.1929, -0.7327], requires_grad=True)
#
# Epoch 3900, Training loss 6.6669, Validation loss 10.7126
#    params tensor([ 0.1933,  0.1933, -0.7500], requires_grad=True)
#
# Epoch 4000, Training loss 6.6371, Validation loss 10.6036
#    params tensor([ 0.1936,  0.1936, -0.7673], requires_grad=True)
#
# Epoch 4100, Training loss 6.6076, Validation loss 10.4956
#    params tensor([ 0.1939,  0.1939, -0.7845], requires_grad=True)
#
# Epoch 4200, Training loss 6.5782, Validation loss 10.3887
#    params tensor([ 0.1942,  0.1942, -0.8016], requires_grad=True)
#
# Epoch 4300, Training loss 6.5491, Validation loss 10.2828
#    params tensor([ 0.1945,  0.1945, -0.8186], requires_grad=True)
#
# Epoch 4400, Training loss 6.5201, Validation loss 10.1780
#    params tensor([ 0.1948,  0.1948, -0.8357], requires_grad=True)
#
# Epoch 4500, Training loss 6.4914, Validation loss 10.0743
#    params tensor([ 0.1951,  0.1951, -0.8526], requires_grad=True)
#
# Epoch 4600, Training loss 6.4629, Validation loss 9.9715
#    params tensor([ 0.1954,  0.1954, -0.8695], requires_grad=True)
#
# Epoch 4700, Training loss 6.4345, Validation loss 9.8698
#    params tensor([ 0.1957,  0.1957, -0.8863], requires_grad=True)
#
# Epoch 4800, Training loss 6.4063, Validation loss 9.7691
#    params tensor([ 0.1960,  0.1960, -0.9031], requires_grad=True)
#
# Epoch 4900, Training loss 6.3784, Validation loss 9.6694
#    params tensor([ 0.1963,  0.1963, -0.9198], requires_grad=True)
#
# Epoch 5000, Training loss 6.3506, Validation loss 9.5707
#    params tensor([ 0.1966,  0.1966, -0.9365], requires_grad=True)
#
# Epoch 5100, Training loss 6.3230, Validation loss 9.4730
#    params tensor([ 0.1969,  0.1969, -0.9531], requires_grad=True)
#
# Epoch 5200, Training loss 6.2956, Validation loss 9.3763
#    params tensor([ 0.1972,  0.1972, -0.9696], requires_grad=True)
#
# Epoch 5300, Training loss 6.2684, Validation loss 9.2806
#    params tensor([ 0.1975,  0.1975, -0.9861], requires_grad=True)
#
# Epoch 5400, Training loss 6.2414, Validation loss 9.1858
#    params tensor([ 0.1977,  0.1977, -1.0025], requires_grad=True)
#
# Epoch 5500, Training loss 6.2145, Validation loss 9.0920
#    params tensor([ 0.1980,  0.1980, -1.0189], requires_grad=True)
#
# Epoch 5600, Training loss 6.1879, Validation loss 8.9991
#    params tensor([ 0.1983,  0.1983, -1.0352], requires_grad=True)
#
# Epoch 5700, Training loss 6.1614, Validation loss 8.9071
#    params tensor([ 0.1986,  0.1986, -1.0515], requires_grad=True)
#
# Epoch 5800, Training loss 6.1351, Validation loss 8.8161
#    params tensor([ 0.1989,  0.1989, -1.0677], requires_grad=True)
#
# Epoch 5900, Training loss 6.1090, Validation loss 8.7261
#    params tensor([ 0.1992,  0.1992, -1.0839], requires_grad=True)
#
# Epoch 6000, Training loss 6.0831, Validation loss 8.6369
#    params tensor([ 0.1995,  0.1995, -1.1000], requires_grad=True)
#
# Epoch 6100, Training loss 6.0573, Validation loss 8.5487
#    params tensor([ 0.1998,  0.1998, -1.1160], requires_grad=True)
#
# Epoch 6200, Training loss 6.0318, Validation loss 8.4614
#    params tensor([ 0.2000,  0.2000, -1.1320], requires_grad=True)
#
# Epoch 6300, Training loss 6.0064, Validation loss 8.3750
#    params tensor([ 0.2003,  0.2003, -1.1479], requires_grad=True)
#
# Epoch 6400, Training loss 5.9811, Validation loss 8.2894
#    params tensor([ 0.2006,  0.2006, -1.1638], requires_grad=True)
#
# Epoch 6500, Training loss 5.9561, Validation loss 8.2048
#    params tensor([ 0.2009,  0.2009, -1.1796], requires_grad=True)
#
# Epoch 6600, Training loss 5.9312, Validation loss 8.1210
#    params tensor([ 0.2012,  0.2012, -1.1954], requires_grad=True)
#
# Epoch 6700, Training loss 5.9065, Validation loss 8.0381
#    params tensor([ 0.2015,  0.2015, -1.2111], requires_grad=True)
#
# Epoch 6800, Training loss 5.8820, Validation loss 7.9561
#    params tensor([ 0.2017,  0.2017, -1.2268], requires_grad=True)
#
# Epoch 6900, Training loss 5.8576, Validation loss 7.8749
#    params tensor([ 0.2020,  0.2020, -1.2424], requires_grad=True)
#
# Epoch 7000, Training loss 5.8334, Validation loss 7.7946
#    params tensor([ 0.2023,  0.2023, -1.2579], requires_grad=True)
#
# Epoch 7100, Training loss 5.8093, Validation loss 7.7151
#    params tensor([ 0.2026,  0.2026, -1.2734], requires_grad=True)
#
# Epoch 7200, Training loss 5.7855, Validation loss 7.6364
#    params tensor([ 0.2028,  0.2028, -1.2889], requires_grad=True)
#
# Epoch 7300, Training loss 5.7618, Validation loss 7.5586
#    params tensor([ 0.2031,  0.2031, -1.3043], requires_grad=True)
#
# Epoch 7400, Training loss 5.7382, Validation loss 7.4816
#    params tensor([ 0.2034,  0.2034, -1.3196], requires_grad=True)
#
# Epoch 7500, Training loss 5.7148, Validation loss 7.4054
#    params tensor([ 0.2037,  0.2037, -1.3349], requires_grad=True)
#
# Epoch 7600, Training loss 5.6916, Validation loss 7.3301
#    params tensor([ 0.2039,  0.2039, -1.3501], requires_grad=True)
#
# Epoch 7700, Training loss 5.6685, Validation loss 7.2555
#    params tensor([ 0.2042,  0.2042, -1.3653], requires_grad=True)
#
# Epoch 7800, Training loss 5.6456, Validation loss 7.1817
#    params tensor([ 0.2045,  0.2045, -1.3804], requires_grad=True)
#
# Epoch 7900, Training loss 5.6229, Validation loss 7.1087
#    params tensor([ 0.2047,  0.2047, -1.3955], requires_grad=True)
#
# Epoch 8000, Training loss 5.6003, Validation loss 7.0366
#    params tensor([ 0.2050,  0.2050, -1.4106], requires_grad=True)
#
# Epoch 8100, Training loss 5.5778, Validation loss 6.9651
#    params tensor([ 0.2053,  0.2053, -1.4255], requires_grad=True)
#
# Epoch 8200, Training loss 5.5555, Validation loss 6.8945
#    params tensor([ 0.2055,  0.2055, -1.4405], requires_grad=True)
#
# Epoch 8300, Training loss 5.5334, Validation loss 6.8246
#    params tensor([ 0.2058,  0.2058, -1.4553], requires_grad=True)
#
# Epoch 8400, Training loss 5.5114, Validation loss 6.7555
#    params tensor([ 0.2061,  0.2061, -1.4702], requires_grad=True)
#
# Epoch 8500, Training loss 5.4896, Validation loss 6.6871
#    params tensor([ 0.2063,  0.2063, -1.4849], requires_grad=True)
#
# Epoch 8600, Training loss 5.4679, Validation loss 6.6195
#    params tensor([ 0.2066,  0.2066, -1.4996], requires_grad=True)
#
# Epoch 8700, Training loss 5.4464, Validation loss 6.5526
#    params tensor([ 0.2068,  0.2068, -1.5143], requires_grad=True)
#
# Epoch 8800, Training loss 5.4250, Validation loss 6.4864
#    params tensor([ 0.2071,  0.2071, -1.5289], requires_grad=True)
#
# Epoch 8900, Training loss 5.4037, Validation loss 6.4210
#    params tensor([ 0.2074,  0.2074, -1.5435], requires_grad=True)
#
# Epoch 9000, Training loss 5.3826, Validation loss 6.3563
#    params tensor([ 0.2076,  0.2076, -1.5580], requires_grad=True)
#
# Epoch 9100, Training loss 5.3617, Validation loss 6.2923
#    params tensor([ 0.2079,  0.2079, -1.5725], requires_grad=True)
#
# Epoch 9200, Training loss 5.3409, Validation loss 6.2290
#    params tensor([ 0.2081,  0.2081, -1.5869], requires_grad=True)
#
# Epoch 9300, Training loss 5.3202, Validation loss 6.1665
#    params tensor([ 0.2084,  0.2084, -1.6013], requires_grad=True)
#
# Epoch 9400, Training loss 5.2997, Validation loss 6.1046
#    params tensor([ 0.2086,  0.2086, -1.6156], requires_grad=True)
#
# Epoch 9500, Training loss 5.2793, Validation loss 6.0434
#    params tensor([ 0.2089,  0.2089, -1.6299], requires_grad=True)
#
# Epoch 9600, Training loss 5.2591, Validation loss 5.9829
#    params tensor([ 0.2091,  0.2091, -1.6441], requires_grad=True)
#
# Epoch 9700, Training loss 5.2390, Validation loss 5.9231
#    params tensor([ 0.2094,  0.2094, -1.6583], requires_grad=True)
#
# Epoch 9800, Training loss 5.2190, Validation loss 5.8640
#    params tensor([ 0.2097,  0.2097, -1.6724], requires_grad=True)
#
# Epoch 9900, Training loss 5.1992, Validation loss 5.8055
#    params tensor([ 0.2099,  0.2099, -1.6865], requires_grad=True)
#
# Epoch 10000, Training loss 5.1795, Validation loss 5.7478
#    params tensor([ 0.2102,  0.2102, -1.7005], requires_grad=True)

# %%
t_p = model(t_un, *params)
# fig = plt.figure(dpi = 600)
plt.xlabel("*F")
plt.ylabel('*C')
plt.plot(t_u.numpy(), t_p.detach().numpy())
plt.plot(t_u.numpy(), t_c.numpy(), 'o')
plt.plot(1,2,'ro')
plt.show()
